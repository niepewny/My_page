# %%
# !aws s3 sync --no-sign-request s3://sevir/data/ir069/ /data
# !pip install dagshub

from dagshub.streaming import DagsHubFilesystem

# fs = DagsHubFilesystem(".", repo_url="https://dagshub.com/DagsHub-Datasets/sevir-dataset")
fs.listdir("s3://sevir")
fs.listdir("s3://sevir/data/ir069/2019")
# !ls s3://sevir/data/ir069/2019
# Out:
# ls: cannot access 's3://sevir/data/ir069/2019': No such file or directory

# %% [markdown]
# # Data Loader

# %%
# !pip install pytorch_lightning
# !pip install torchmetrics
import h5py
import torch
from torch.utils.data import DataLoader, Dataset, Subset
import pytorch_lightning as pl
from torch.nn import functional as F
import os
import math
from torchvision import transforms
# from data_exploration import visualize_batch_tensor_interactive
import os
import s3fs
os.environ["HDF5_USE_FILE_LOCKING"]='FALSE'
# Out:
# Requirement already satisfied: pytorch_lightning in /home/kolaj/my_project/AI/venvAI/lib/python3.12/site-packages (2.5.0.post0)
# Requirement already satisfied: torch>=2.1.0 in /home/kolaj/my_project/AI/venvAI/lib/python3.12/site-packages (from pytorch_lightning) (2.5.1)
# Requirement already satisfied: tqdm>=4.57.0 in /home/kolaj/my_project/AI/venvAI/lib/python3.12/site-packages (from pytorch_lightning) (4.66.4)
# Requirement already satisfied: PyYAML>=5.4 in /home/kolaj/my_project/AI/venvAI/lib/python3.12/site-packages (from pytorch_lightning) (6.0.1)
# Requirement already satisfied: fsspec>=2022.5.0 in /home/kolaj/my_project/AI/venvAI/lib/python3.12/site-packages (from fsspec[http]>=2022.5.0->pytorch_lightning) (2024.12.0)
# Requirement already satisfied: torchmetrics>=0.7.0 in /home/kolaj/my_project/AI/venvAI/lib/python3.12/site-packages (from pytorch_lightning) (1.6.1)
# Requirement already satisfied: packaging>=20.0 in /home/kolaj/my_project/AI/venvAI/lib/python3.12/site-packages (from pytorch_lightning) (24.0)
# Requirement already satisfied: typing-extensions>=4.4.0 in /home/kolaj/my_project/AI/venvAI/lib/python3.12/site-packages (from pytorch_lightning) (4.12.2)
# Requirement already satisfied: lightning-utilities>=0.10.0 in /home/kolaj/my_project/AI/venvAI/lib/python3.12/site-packages (from pytorch_lightning) (0.11.9)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /home/kolaj/my_project/AI/venvAI/lib/python3.12/site-packages (from fsspec[http]>=2022.5.0->pytorch_lightning) (3.11.11)
# Requirement already satisfied: setuptools in /home/kolaj/my_project/AI/venvAI/lib/python3.12/site-packages (from lightning-utilities>=0.10.0->pytorch_lightning) (69.2.0)
# Requirement already satisfied: filelock in /home/kolaj/my_project/AI/venvAI/lib/python3.12/site-packages (from torch>=2.1.0->pytorch_lightning) (3.16.1)
# Requirement already satisfied: networkx in /home/kolaj/my_project/AI/venvAI/lib/python3.12/site-packages (from torch>=2.1.0->pytorch_lightning) (3.3)
# Requirement already satisfied: jinja2 in /home/kolaj/my_project/AI/venvAI/lib/python3.12/site-packages (from torch>=2.1.0->pytorch_lightning) (3.1.3)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /home/kolaj/my_project/AI/venvAI/lib/python3.12/site-packages (from torch>=2.1.0->pytorch_lightning) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /home/kolaj/my_project/AI/venvAI/lib/python3.12/site-packages (from torch>=2.1.0->pytorch_lightning) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /home/kolaj/my_project/AI/venvAI/lib/python3.12/site-packages (from torch>=2.1.0->pytorch_lightning) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/kolaj/my_project/AI/venvAI/lib/python3.12/site-packages (from torch>=2.1.0->pytorch_lightning) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /home/kolaj/my_project/AI/venvAI/lib/python3.12/site-packages (from torch>=2.1.0->pytorch_lightning) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /home/kolaj/my_project/AI/venvAI/lib/python3.12/site-packages (from torch>=2.1.0->pytorch_lightning) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /home/kolaj/my_project/AI/venvAI/lib/python3.12/site-packages (from torch>=2.1.0->pytorch_lightning) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /home/kolaj/my_project/AI/venvAI/lib/python3.12/site-packages (from torch>=2.1.0->pytorch_lightning) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /home/kolaj/my_project/AI/venvAI/lib/python3.12/site-packages (from torch>=2.1.0->pytorch_lightning) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/kolaj/my_project/AI/venvAI/lib/python3.12/site-packages (from torch>=2.1.0->pytorch_lightning) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /home/kolaj/my_project/AI/venvAI/lib/python3.12/site-packages (from torch>=2.1.0->pytorch_lightning) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /home/kolaj/my_project/AI/venvAI/lib/python3.12/site-packages (from torch>=2.1.0->pytorch_lightning) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /home/kolaj/my_project/AI/venvAI/lib/python3.12/site-packages (from torch>=2.1.0->pytorch_lightning) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /home/kolaj/my_project/AI/venvAI/lib/python3.12/site-packages (from torch>=2.1.0->pytorch_lightning) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/kolaj/my_project/AI/venvAI/lib/python3.12/site-packages (from sympy==1.13.1->torch>=2.1.0->pytorch_lightning) (1.3.0)
# Requirement already satisfied: numpy>1.20.0 in /home/kolaj/my_project/AI/venvAI/lib/python3.12/site-packages (from torchmetrics>=0.7.0->pytorch_lightning) (1.26.4)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/kolaj/my_project/AI/venvAI/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/kolaj/my_project/AI/venvAI/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /home/kolaj/my_project/AI/venvAI/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/kolaj/my_project/AI/venvAI/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/kolaj/my_project/AI/venvAI/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/kolaj/my_project/AI/venvAI/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/kolaj/my_project/AI/venvAI/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (1.18.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/kolaj/my_project/AI/venvAI/lib/python3.12/site-packages (from jinja2->torch>=2.1.0->pytorch_lightning) (2.1.5)
# Requirement already satisfied: idna>=2.0 in /home/kolaj/my_project/AI/venvAI/lib/python3.12/site-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (3.6)
# Requirement already satisfied: torchmetrics in /home/kolaj/my_project/AI/venvAI/lib/python3.12/site-packages (1.6.1)
# Requirement already satisfied: numpy>1.20.0 in /home/kolaj/my_project/AI/venvAI/lib/python3.12/site-packages (from torchmetrics) (1.26.4)
# Requirement already satisfied: packaging>17.1 in /home/kolaj/my_project/AI/venvAI/lib/python3.12/site-packages (from torchmetrics) (24.0)
# Requirement already satisfied: torch>=2.0.0 in /home/kolaj/my_project/AI/venvAI/lib/python3.12/site-packages (from torchmetrics) (2.5.1)
# Requirement already satisfied: lightning-utilities>=0.8.0 in /home/kolaj/my_project/AI/venvAI/lib/python3.12/site-packages (from torchmetrics) (0.11.9)
# Requirement already satisfied: setuptools in /home/kolaj/my_project/AI/venvAI/lib/python3.12/site-packages (from lightning-utilities>=0.8.0->torchmetrics) (69.2.0)
# Requirement already satisfied: typing-extensions in /home/kolaj/my_project/AI/venvAI/lib/python3.12/site-packages (from lightning-utilities>=0.8.0->torchmetrics) (4.12.2)
# Requirement already satisfied: filelock in /home/kolaj/my_project/AI/venvAI/lib/python3.12/site-packages (from torch>=2.0.0->torchmetrics) (3.16.1)
# Requirement already satisfied: networkx in /home/kolaj/my_project/AI/venvAI/lib/python3.12/site-packages (from torch>=2.0.0->torchmetrics) (3.3)
# Requirement already satisfied: jinja2 in /home/kolaj/my_project/AI/venvAI/lib/python3.12/site-packages (from torch>=2.0.0->torchmetrics) (3.1.3)
# Requirement already satisfied: fsspec in /home/kolaj/my_project/AI/venvAI/lib/python3.12/site-packages (from torch>=2.0.0->torchmetrics) (2024.12.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /home/kolaj/my_project/AI/venvAI/lib/python3.12/site-packages (from torch>=2.0.0->torchmetrics) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /home/kolaj/my_project/AI/venvAI/lib/python3.12/site-packages (from torch>=2.0.0->torchmetrics) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /home/kolaj/my_project/AI/venvAI/lib/python3.12/site-packages (from torch>=2.0.0->torchmetrics) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/kolaj/my_project/AI/venvAI/lib/python3.12/site-packages (from torch>=2.0.0->torchmetrics) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /home/kolaj/my_project/AI/venvAI/lib/python3.12/site-packages (from torch>=2.0.0->torchmetrics) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /home/kolaj/my_project/AI/venvAI/lib/python3.12/site-packages (from torch>=2.0.0->torchmetrics) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /home/kolaj/my_project/AI/venvAI/lib/python3.12/site-packages (from torch>=2.0.0->torchmetrics) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /home/kolaj/my_project/AI/venvAI/lib/python3.12/site-packages (from torch>=2.0.0->torchmetrics) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /home/kolaj/my_project/AI/venvAI/lib/python3.12/site-packages (from torch>=2.0.0->torchmetrics) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/kolaj/my_project/AI/venvAI/lib/python3.12/site-packages (from torch>=2.0.0->torchmetrics) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /home/kolaj/my_project/AI/venvAI/lib/python3.12/site-packages (from torch>=2.0.0->torchmetrics) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /home/kolaj/my_project/AI/venvAI/lib/python3.12/site-packages (from torch>=2.0.0->torchmetrics) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /home/kolaj/my_project/AI/venvAI/lib/python3.12/site-packages (from torch>=2.0.0->torchmetrics) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /home/kolaj/my_project/AI/venvAI/lib/python3.12/site-packages (from torch>=2.0.0->torchmetrics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/kolaj/my_project/AI/venvAI/lib/python3.12/site-packages (from sympy==1.13.1->torch>=2.0.0->torchmetrics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/kolaj/my_project/AI/venvAI/lib/python3.12/site-packages (from jinja2->torch>=2.0.0->torchmetrics) (2.1.5)

# %%
TIME_STEPS = 49

class SEVIR_dataset(Dataset):
    """
    Dataset ładujący dane SEVIR z wielu plików HDF5.
    """
    def __init__(self, samples_dir_path, step, width, height, sequence_length):
        super().__init__()
        # crawl directory to retrive paths to h5 files absolute paths
        self.file_paths = self._get_h5_files(samples_dir_path)
        self.samples_per_file = []
        self._cumulative_indices = []
        self.step = step
        self.width = width
        self.height = height
        self.sequence_length = sequence_length


        current_cum = 0
        for path in self.file_paths:
            if not os.path.exists(path):
                raise FileNotFoundError(f"File not found: {path}")

            with h5py.File(path, 'r') as f:
                data_shape = f['ir069'].shape
                x_size = data_shape[0]
                self.samples_per_file.append(x_size)
                current_cum += x_size
                self._cumulative_indices.append(current_cum)

    def __len__(self):
        return self._cumulative_indices[-1]

    def __getitem__(self, index):
        # Znajdujemy indeks pliku, w którym znajduje się żądana próbka
        file_idx = self._find_file_index(index)

        # Obliczamy lokalny indeks w znalezionym pliku:
        # - Dla pierwszego pliku (idx=0) indeks lokalny = indeks globalny
        # - Dla kolejnych plików odejmujemy sumę próbek z poprzednich plików
        if file_idx == 0:
            local_index = index
        else:
            local_index = index - self._cumulative_indices[file_idx - 1]

        file_path = self.file_paths[file_idx]

        '''
        pipeline przetwarzania próbek:
        1. lazy loading na podstawie indeksu lokalnego
        2. zamiana z 192x192x49 na 49x192x192
        3. pobranie co ntej klatki czasowej - np przy kroku 2 zamiana na 25x192x192
        4. zmiana rozmiaru na np. 25 x height x width
        5. normalizacja z zakresu 0-255 na 0-1
        '''
        if self.sequence_length > math.ceil(TIME_STEPS/self.step):
                        raise ValueError(f"sequence_length {self.sequence_length} is greater than available frames {math.ceil(TIME_STEPS/self.step)} (TIME_STEPS/step)")

        try:
            # otwarcie sampla z pliku za pomocą indeksu lokalnego(własciwego dla danego pliku)
            with h5py.File(file_path, 'r') as f:
                sample = f['ir069'][local_index]
                sample = torch.tensor(sample, dtype=torch.float32)
                # zamienia z 192x192x49 na 49x192x192
                permuted_sample = sample.permute(2, 0, 1)
                # przy kroku 2 zamienia na 25x192x192
                permuted_sample_step = self._get_sample_with_step(permuted_sample, self.step)
                # check czy oczekiwana długość jest mniejsza niż wzięcie co ntej klatki, a torch robi ceil przy samplowaniu
                if self.sequence_length <= math.ceil(TIME_STEPS/self.step):
                    permuted_sample_step_len = permuted_sample_step[:self.sequence_length]
                # zmiana rozmiaru na na np. 25 x height x width
                if self.width != 192 or self.height != 192:
                    resize = transforms.Resize((self.height, self.width), antialias=True)
                    permuted_sample_step_resized = resize(permuted_sample_step_len)
                else:
                    permuted_sample_step_resized = permuted_sample_step
                # normalizacja z zakresu 0-255 na 0-1
                permuted_sample_step_resized_normalized = permuted_sample_step_resized / 1000
                permuted_sample_step_resized_normalized_channel = permuted_sample_step_resized_normalized.unsqueeze(1)

                return permuted_sample_step_resized_normalized_channel

        except Exception as e:
            print(f"Error loading file {file_path} at index {local_index}")
            raise e

    def _get_h5_files(self, directory):
        """
        Recursively finds all .h5 files in the given directory and its subdirectories.
        Returns list: A list of absolute paths to .h5 files.
        """
        h5_files = []
        for root, _, files in os.walk(directory):
            for file in files:
                if file.endswith('.h5'):  # Check for .h5 extension
                    h5_files.append(os.path.abspath(os.path.join(root, file)))
        return h5_files

    def _find_file_index(self, index):
        for i, cum in enumerate(self._cumulative_indices):
            if index < cum:
                return i
        raise IndexError(f"Index {index} out of range {self.__len__()}")

    def _get_sample_with_step(self,tensor,step):
        """
        Zwraca klatki z tensora z krokiem step.
        """
        frames = []
        for i in range(0, tensor.shape[0], step):
            frame = tensor[i]
            frames.append(frame)
        return torch.stack(frames)

# %%
class ConvLSTMSevirDataModule(pl.LightningDataModule):
    """
    DataModule dla projektu z convLSTM na zbiorze SEVIR (kanał IR069).
    W metodzie setup 3 dataset-y (train, val, test)
    Domyślnie przypisujemy podział plików test,train,val jak na górze pliku.
    """

    def __init__(
        self,
        # parametry transformacji danych
        step,
        width,
        height,
        sequence_length,
        # przypisanie plików do zbiorów
        files_dir,
        # parametry DataLoadera
        batch_size=4,
        num_workers=2,
        train_files_percent=70,
        val_files_percent=15,
        test_files_percent=15
    ):
        super().__init__()
        self.batch_size = batch_size
        self.num_workers = num_workers
        self.files_dir = files_dir
        self.step = step
        self.width = width
        self.height = height
        self.sequence_length = sequence_length
        self.train_files_percent = train_files_percent
        self.val_files_percent = val_files_percent
        self.test_files_percent = test_files_percent

        self.train_dataset = None
        self.val_dataset = None
        self.test_dataset = None


    def prepare_data(self):
        # zakładamy że pliki są już lokalnie.
        # pobrane komendą z README
        pass

    def setup(self, stage=None):
        # Tworzymy dataset-y.
        full_dataset = SEVIR_dataset(
            self.files_dir,
            self.step,
            self.width,
            self.height,
            self.sequence_length)
        train_dataset, val_dataset, test_dataset = torch.utils.data.random_split(
            full_dataset,
            [self.train_files_percent, self.val_files_percent, self.test_files_percent])

        if stage == 'fit' or stage is None:
            self.train_dataset = train_dataset
            self.val_dataset   = val_dataset

        if stage == 'test' or stage is None:
            self.test_dataset  = test_dataset

    def train_dataloader(self):
        return DataLoader(
            self.train_dataset,
            batch_size=self.batch_size,
            shuffle=True,
            num_workers=self.num_workers
        )

    def val_dataloader(self):
        return DataLoader(
            self.val_dataset,
            batch_size=self.batch_size,
            shuffle=False,
            num_workers=self.num_workers
        )

    def test_dataloader(self):
        return DataLoader(
            self.test_dataset,
            batch_size=self.batch_size,
            shuffle=False,
            num_workers=self.num_workers
        )

# %%
fs.listdir("s3://sevir")
fs.listdir("s3://sevir/data/ir069/2019")

s3 = s3fs.S3FileSystem()
f = h5py.File(s3.open("s3://my-sevir/data/ir069/2019", "rb"))
# Out:
# ---------------------------------------------------------------------------
# NoCredentialsError                        Traceback (most recent call last)
# Cell In[19], line 5
#       2 fs.listdir("s3://sevir/data/ir069/2019")
#       4 s3 = s3fs.S3FileSystem()
# ----> 5 f = h5py.File(s3.open("s3://my-bucket/my-file.h5", "rb"))
#
# File ~/my_project/AI/venvAI/lib/python3.12/site-packages/fsspec/spec.py:1301, in open(self, path, mode, block_size, cache_options, compression, **kwargs)
#    1290     mode = mode.replace("t", "") + "b"
#    1292     text_kwargs = {
#    1293         k: kwargs.pop(k)
#    1294         for k in ["encoding", "errors", "newline"]
#    1295         if k in kwargs
#    1296     }
#    1297     return io.TextIOWrapper(
#    1298         self.open(
#    1299             path,
#    1300             mode,
# -> 1301             block_size=block_size,
#    1302             cache_options=cache_options,
#    1303             compression=compression,
#    1304             **kwargs,
#    1305         ),
#    1306         **text_kwargs,
#    1307     )
#    1308 else:
#    1309     ac = kwargs.pop("autocommit", not self._intrans)
#
# File ~/my_project/AI/venvAI/lib/python3.12/site-packages/s3fs/core.py:699, in S3FileSystem._open(self, path, mode, block_size, acl, version_id, fill_cache, cache_type, autocommit, size, requester_pays, cache_options, **kwargs)
#     696 if cache_type is None:
#     697     cache_type = self.default_cache_type
# --> 699 return S3File(
#     700     self,
#     701     path,
#     702     mode,
#     703     block_size=block_size,
#     704     acl=acl,
#     705     version_id=version_id,
#     706     fill_cache=fill_cache,
#     707     s3_additional_kwargs=kw,
#     708     cache_type=cache_type,
#     709     autocommit=autocommit,
#     710     requester_pays=requester_pays,
#     711     cache_options=cache_options,
#     712     size=size,
#     713 )
#
# File ~/my_project/AI/venvAI/lib/python3.12/site-packages/s3fs/core.py:2238, in S3File.__init__(self, s3, path, mode, block_size, acl, version_id, fill_cache, s3_additional_kwargs, autocommit, cache_type, requester_pays, cache_options, size)
#    2236         self.details = s3.info(path)
#    2237         self.version_id = self.details.get("VersionId")
# -> 2238 super().__init__(
#    2239     s3,
#    2240     path,
#    2241     mode,
#    2242     block_size,
#    2243     autocommit=autocommit,
#    2244     cache_type=cache_type,
#    2245     cache_options=cache_options,
#    2246     size=size,
#    2247 )
#    2248 self.s3 = self.fs  # compatibility
#    2250 # when not using autocommit we want to have transactional state to manage
#
# File ~/my_project/AI/venvAI/lib/python3.12/site-packages/fsspec/spec.py:1740, in __init__(self, fs, path, mode, block_size, autocommit, cache_type, cache_options, size, **kwargs)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File ~/my_project/AI/venvAI/lib/python3.12/site-packages/fsspec/spec.py:1753, in details(self)
#    1750     """Alias of `AbstractFileSystem.du`."""
#    1751     return self.du(path, total=total, maxdepth=maxdepth, **kwargs)
# -> 1753 def rename(self, path1, path2, **kwargs):
#    1754     """Alias of `AbstractFileSystem.mv`."""
#    1755     return self.mv(path1, path2, **kwargs)
#
# File ~/my_project/AI/venvAI/lib/python3.12/site-packages/fsspec/asyn.py:118, in sync_wrapper.<locals>.wrapper(*args, **kwargs)
#     115 @functools.wraps(func)
#     116 def wrapper(*args, **kwargs):
#     117     self = obj or args[0]
# --> 118     return sync(self.loop, func, *args, **kwargs)
#
# File ~/my_project/AI/venvAI/lib/python3.12/site-packages/fsspec/asyn.py:103, in sync(loop, func, timeout, *args, **kwargs)
#     101     raise FSTimeoutError from return_result
#     102 elif isinstance(return_result, BaseException):
# --> 103     raise return_result
#     104 else:
#     105     return return_result
#
# File ~/my_project/AI/venvAI/lib/python3.12/site-packages/fsspec/asyn.py:56, in _runner(event, coro, result, timeout)
#      54     coro = asyncio.wait_for(coro, timeout=timeout)
#      55 try:
# ---> 56     result[0] = await coro
#      57 except Exception as ex:
#      58     result[0] = ex
#
# File ~/my_project/AI/venvAI/lib/python3.12/site-packages/s3fs/core.py:1426, in S3FileSystem._info(self, path, bucket, key, refresh, version_id)
#    1424 if key:
#    1425     try:
# -> 1426         out = await self._call_s3(
#    1427             "head_object",
#    1428             self.kwargs,
#    1429             Bucket=bucket,
#    1430             Key=key,
#    1431             **version_id_kw(version_id),
#    1432             **self.req_kw,
#    1433         )
#    1434         return {
#    1435             "ETag": out.get("ETag", ""),
#    1436             "LastModified": out.get("LastModified", ""),
#    (...)
#    1442             "ContentType": out.get("ContentType"),
#    1443         }
#    1444     except FileNotFoundError:
#
# File ~/my_project/AI/venvAI/lib/python3.12/site-packages/s3fs/core.py:371, in S3FileSystem._call_s3(self, method, *akwarglist, **kwargs)
#     369 logger.debug("CALL: %s - %s - %s", method.__name__, akwarglist, kw2)
#     370 additional_kwargs = self._get_s3_method_kwargs(method, *akwarglist, **kwargs)
# --> 371 return await _error_wrapper(
#     372     method, kwargs=additional_kwargs, retries=self.retries
#     373 )
#
# File ~/my_project/AI/venvAI/lib/python3.12/site-packages/s3fs/core.py:146, in _error_wrapper(func, args, kwargs, retries)
#     144         err = e
#     145 err = translate_boto_error(err)
# --> 146 raise err
#
# File ~/my_project/AI/venvAI/lib/python3.12/site-packages/s3fs/core.py:114, in _error_wrapper(func, args, kwargs, retries)
#     112 for i in range(retries):
#     113     try:
# --> 114         return await func(*args, **kwargs)
#     115     except S3_RETRYABLE_ERRORS as e:
#     116         err = e
#
# File ~/my_project/AI/venvAI/lib/python3.12/site-packages/aiobotocore/client.py:394, in AioBaseClient._make_api_call(self, operation_name, api_params)
#     390     maybe_compress_request(
#     391         self.meta.config, request_dict, operation_model
#     392     )
#     393     apply_request_checksum(request_dict)
# --> 394     http, parsed_response = await self._make_request(
#     395         operation_model, request_dict, request_context
#     396     )
#     398 await self.meta.events.emit(
#     399     f'after-call.{service_id}.{operation_name}',
#     400     http_response=http,
#    (...)
#     403     context=request_context,
#     404 )
#     406 if http.status_code >= 300:
#
# File ~/my_project/AI/venvAI/lib/python3.12/site-packages/aiobotocore/client.py:420, in AioBaseClient._make_request(self, operation_model, request_dict, request_context)
#     416 async def _make_request(
#     417     self, operation_model, request_dict, request_context
#     418 ):
#     419     try:
# --> 420         return await self._endpoint.make_request(
#     421             operation_model, request_dict
#     422         )
#     423     except Exception as e:
#     424         await self.meta.events.emit(
#     425             f'after-call-error.{self._service_model.service_id.hyphenize()}.{operation_model.name}',
#     426             exception=e,
#     427             context=request_context,
#     428         )
#
# File ~/my_project/AI/venvAI/lib/python3.12/site-packages/aiobotocore/endpoint.py:96, in AioEndpoint._send_request(self, request_dict, operation_model)
#      94 context = request_dict['context']
#      95 self._update_retries_context(context, attempts)
# ---> 96 request = await self.create_request(request_dict, operation_model)
#      97 success_response, exception = await self._get_response(
#      98     request, operation_model, context
#      99 )
#     100 while await self._needs_retry(
#     101     attempts,
#     102     operation_model,
#    (...)
#     105     exception,
#     106 ):
#
# File ~/my_project/AI/venvAI/lib/python3.12/site-packages/aiobotocore/endpoint.py:84, in AioEndpoint.create_request(self, params, operation_model)
#      82     service_id = operation_model.service_model.service_id.hyphenize()
#      83     event_name = f'request-created.{service_id}.{operation_model.name}'
# ---> 84     await self._event_emitter.emit(
#      85         event_name,
#      86         request=request,
#      87         operation_name=operation_model.name,
#      88     )
#      89 prepared_request = self.prepare_request(request)
#      90 return prepared_request
#
# File ~/my_project/AI/venvAI/lib/python3.12/site-packages/aiobotocore/hooks.py:68, in AioHierarchicalEmitter._emit(self, event_name, kwargs, stop_on_response)
#      65 logger.debug('Event %s: calling handler %s', event_name, handler)
#      67 # Await the handler if its a coroutine.
# ---> 68 response = await resolve_awaitable(handler(**kwargs))
#      69 responses.append((handler, response))
#      70 if stop_on_response and response is not None:
#
# File ~/my_project/AI/venvAI/lib/python3.12/site-packages/aiobotocore/_helpers.py:6, in resolve_awaitable(obj)
#       4 async def resolve_awaitable(obj):
#       5     if inspect.isawaitable(obj):
# ----> 6         return await obj
#       8     return obj
#
# File ~/my_project/AI/venvAI/lib/python3.12/site-packages/aiobotocore/signers.py:24, in AioRequestSigner.handler(self, operation_name, request, **kwargs)
#      19 async def handler(self, operation_name=None, request=None, **kwargs):
#      20     # This is typically hooked up to the "request-created" event
#      21     # from a client's event emitter.  When a new request is created
#      22     # this method is invoked to sign the request.
#      23     # Don't call this method directly.
# ---> 24     return await self.sign(operation_name, request)
#
# File ~/my_project/AI/venvAI/lib/python3.12/site-packages/aiobotocore/signers.py:90, in AioRequestSigner.sign(self, operation_name, request, region_name, signing_type, expires_in, signing_name)
#      87     else:
#      88         raise e
# ---> 90 auth.add_auth(request)
#
# File ~/my_project/AI/venvAI/lib/python3.12/site-packages/botocore/auth.py:423, in SigV4Auth.add_auth(self, request)
#     421 def add_auth(self, request):
#     422     if self.credentials is None:
# --> 423         raise NoCredentialsError()
#     424     datetime_now = datetime.datetime.utcnow()
#     425     request.context['timestamp'] = datetime_now.strftime(SIGV4_TIMESTAMP)
#
# NoCredentialsError: Unable to locate credentials

# %%
''' przykład użycia oba przykłady są równoważne '''
# tylko jeden jest na pytorch a drugi na pytorch lighnting


''' pytorch dataset '''
s3 = s3fs.S3FileSystem()

file_path_h5_dir = "/data/ir069/2019"
# przyjmuje step oraz szerokość i wysokość obrazka, oraz długość sekwencji(ucinamy 2 klatki tutaj)
full_dataset = SEVIR_dataset(file_path_h5_dir, 3, 128, 128, 15)
print(full_dataset.samples_per_file[0])

print(full_dataset)
# podział na zbiory, procentowy
train_dataset,  val_dataset, test_dataset = torch.utils.data.random_split(full_dataset, [0.7, 0.15, 0.15])
# przykładowy dataloader dla train datasetu
dataloader = DataLoader(train_dataset, batch_size=4, shuffle=True, num_workers=1)
fist_sample = next(iter(dataloader))
print("data loader",fist_sample.shape) # zwraca torch.Size([10, 17, 128, 128])
print("sample split data loader",len(train_dataset),len(val_dataset),len(test_dataset),"\n")
# visualize_batch_tensor_interactive(fist_sample, 0, "SEVIR dataset")

''' pytorch lightning datamodule '''
# # przykład użycia
dm = ConvLSTMSevirDataModule(
    step=3,
    width=128,
    height=128,
    batch_size=4,
    num_workers=1,
    sequence_length=15,
    train_files_percent=0.7,
    val_files_percent=0.15,
    test_files_percent=0.15,
    files_dir=file_path_h5_dir)

dm.setup('fit')
train_loader = dm.train_dataloader()
val_loader = dm.val_dataloader
dm.setup('test')
test_loader = dm.test_dataloader
batch = next(iter(train_loader))
print("data module",batch.shape) # zwraca torch.Size([4, 17, 128, 128
print("sample split data loader",len(dm.train_dataset),len(dm.val_dataset),len(dm.test_dataset))
# visualize_batch_tensor_interactive(batch, 0, "SEVIR dataset")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[20], line 10
#       8 # przyjmuje step oraz szerokość i wysokość obrazka, oraz długość sekwencji(ucinamy 2 klatki tutaj)
#       9 full_dataset = SEVIR_dataset(file_path_h5_dir, 3, 128, 128, 15)
# ---> 10 print(full_dataset.samples_per_file[0])
#      12 print(full_dataset)
#      13 # podział na zbiory, procentowy
#
# IndexError: list index out of range

# %%
import os
import math
import h5py
import torch
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
import s3fs
from pytorch_lightning import LightningDataModule

# Initialize S3 file system
s3 = s3fs.S3FileSystem(anon=False)

# Define constants
TIME_STEPS = 49  # Total time steps in the dataset

class SEVIR_dataset(Dataset):
    """
    Dataset for loading SEVIR data directly from S3 using s3fs.
    """
    def __init__(self, samples_dir_path, step, width, height, sequence_length):
        super().__init__()
        self.file_paths = self._get_h5_files(samples_dir_path)
        self.samples_per_file = []
        self._cumulative_indices = []
        self.step = step
        self.width = width
        self.height = height
        self.sequence_length = sequence_length

        current_cum = 0
        for path in self.file_paths:
            with s3.open(path, 'rb') as f:
                with h5py.File(f, 'r') as h5file:
                    data_shape = h5file['ir069'].shape
                    x_size = data_shape[0]
                    self.samples_per_file.append(x_size)
                    current_cum += x_size
                    self._cumulative_indices.append(current_cum)

    def __len__(self):
        return self._cumulative_indices[-1]

    def __getitem__(self, index):
        file_idx = self._find_file_index(index)

        # Calculate local index within the file
        local_index = index if file_idx == 0 else index - self._cumulative_indices[file_idx - 1]
        file_path = self.file_paths[file_idx]

        with s3.open(file_path, 'rb') as f:
            with h5py.File(f, 'r') as h5file:
                sample = h5file['ir069'][local_index]
                sample = torch.tensor(sample, dtype=torch.float32)
                permuted_sample = sample.permute(2, 0, 1)
                permuted_sample_step = self._get_sample_with_step(permuted_sample, self.step)

                if self.sequence_length <= math.ceil(TIME_STEPS / self.step):
                    permuted_sample_step_len = permuted_sample_step[:self.sequence_length]

                if self.width != 192 or self.height != 192:
                    resize = transforms.Resize((self.height, self.width), antialias=True)
                    permuted_sample_step_resized = resize(permuted_sample_step_len)
                else:
                    permuted_sample_step_resized = permuted_sample_step

                permuted_sample_step_resized_normalized = permuted_sample_step_resized / 1000
                permuted_sample_step_resized_normalized_channel = permuted_sample_step_resized_normalized.unsqueeze(1)

                return permuted_sample_step_resized_normalized_channel

    def _get_h5_files(self, directory):
        """
        Find all .h5 files in the S3 directory.
        """
        return [os.path.join(directory, file) for file in s3.ls(directory) if file.endswith('.h5')]

    def _find_file_index(self, index):
        for i, cum in enumerate(self._cumulative_indices):
            if index < cum:
                return i
        raise IndexError(f"Index {index} out of range {self.__len__()}")

    def _get_sample_with_step(self, tensor, step):
        frames = [tensor[i] for i in range(0, tensor.shape[0], step)]
        return torch.stack(frames)

class ConvLSTMSevirDataModule(LightningDataModule):
    def __init__(self, step, width, height, batch_size, num_workers, sequence_length,
                 train_files_percent, val_files_percent, test_files_percent, files_dir):
        super().__init__()
        self.step = step
        self.width = width
        self.height = height
        self.batch_size = batch_size
        self.num_workers = num_workers
        self.sequence_length = sequence_length
        self.train_files_percent = train_files_percent
        self.val_files_percent = val_files_percent
        self.test_files_percent = test_files_percent
        self.files_dir = files_dir

    def setup(self, stage=None):
        full_dataset = SEVIR_dataset(self.files_dir, self.step, self.width, self.height, self.sequence_length)
        train_size = int(self.train_files_percent * len(full_dataset))
        val_size = int(self.val_files_percent * len(full_dataset))
        test_size = len(full_dataset) - train_size - val_size

        self.train_dataset, self.val_dataset, self.test_dataset = torch.utils.data.random_split(
            full_dataset, [train_size, val_size, test_size]
        )

    def train_dataloader(self):
        return DataLoader(self.train_dataset, batch_size=self.batch_size, shuffle=True, num_workers=self.num_workers)

    def val_dataloader(self):
        return DataLoader(self.val_dataset, batch_size=self.batch_size, shuffle=False, num_workers=self.num_workers)

    def test_dataloader(self):
        return DataLoader(self.test_dataset, batch_size=self.batch_size, shuffle=False, num_workers=self.num_workers)

# Example usage for PyTorch
file_path_h5_dir = "s3://sevir/data/ir069/"
full_dataset = SEVIR_dataset(file_path_h5_dir, 3, 128, 128, 15)
train_dataset, val_dataset, test_dataset = torch.utils.data.random_split(full_dataset, [0.7, 0.15, 0.15])
dataloader = DataLoader(train_dataset, batch_size=4, shuffle=True, num_workers=1)

# Example usage for PyTorch Lightning
dm = ConvLSTMSevirDataModule(
    step=3, width=128, height=128, batch_size=4, num_workers=1, sequence_length=15,
    train_files_percent=0.7, val_files_percent=0.15, test_files_percent=0.15, files_dir=file_path_h5_dir
)

dm.setup('fit')
train_loader = dm.train_dataloader()
batch = next(iter(train_loader))
print("Data module batch shape:", batch.shape)
# Out:
# ---------------------------------------------------------------------------
# NoCredentialsError                        Traceback (most recent call last)
# Cell In[24], line 123
#     121 # Example usage for PyTorch
#     122 file_path_h5_dir = "s3://sevir/data/ir069/"
# --> 123 full_dataset = SEVIR_dataset(file_path_h5_dir, 3, 128, 128, 15)
#     124 train_dataset, val_dataset, test_dataset = torch.utils.data.random_split(full_dataset, [0.7, 0.15, 0.15])
#     125 dataloader = DataLoader(train_dataset, batch_size=4, shuffle=True, num_workers=1)
#
# Cell In[24], line 22, in SEVIR_dataset.__init__(self, samples_dir_path, step, width, height, sequence_length)
#      20 def __init__(self, samples_dir_path, step, width, height, sequence_length):
#      21     super().__init__()
# ---> 22     self.file_paths = self._get_h5_files(samples_dir_path)
#      23     self.samples_per_file = []
#      24     self._cumulative_indices = []
#
# Cell In[24], line 75, in SEVIR_dataset._get_h5_files(self, directory)
#      71 def _get_h5_files(self, directory):
#      72     """
#      73     Find all .h5 files in the S3 directory.
#      74     """
# ---> 75     return [os.path.join(directory, file) for file in s3.ls(directory) if file.endswith('.h5')]
#
# File ~/my_project/AI/venvAI/lib/python3.12/site-packages/fsspec/asyn.py:118, in sync_wrapper.<locals>.wrapper(*args, **kwargs)
#     115 @functools.wraps(func)
#     116 def wrapper(*args, **kwargs):
#     117     self = obj or args[0]
# --> 118     return sync(self.loop, func, *args, **kwargs)
#
# File ~/my_project/AI/venvAI/lib/python3.12/site-packages/fsspec/asyn.py:103, in sync(loop, func, timeout, *args, **kwargs)
#     101     raise FSTimeoutError from return_result
#     102 elif isinstance(return_result, BaseException):
# --> 103     raise return_result
#     104 else:
#     105     return return_result
#
# File ~/my_project/AI/venvAI/lib/python3.12/site-packages/fsspec/asyn.py:56, in _runner(event, coro, result, timeout)
#      54     coro = asyncio.wait_for(coro, timeout=timeout)
#      55 try:
# ---> 56     result[0] = await coro
#      57 except Exception as ex:
#      58     result[0] = ex
#
# File ~/my_project/AI/venvAI/lib/python3.12/site-packages/s3fs/core.py:1019, in S3FileSystem._ls(self, path, detail, refresh, versions)
#    1017     files = await self._lsbuckets(refresh)
#    1018 else:
# -> 1019     files = await self._lsdir(path, refresh, versions=versions)
#    1020     if not files and "/" in path:
#    1021         try:
#
# File ~/my_project/AI/venvAI/lib/python3.12/site-packages/s3fs/core.py:734, in S3FileSystem._lsdir(self, path, refresh, max_items, delimiter, prefix, versions)
#     732 dirs = []
#     733 files = []
# --> 734 async for c in self._iterdir(
#     735     bucket,
#     736     max_items=max_items,
#     737     delimiter=delimiter,
#     738     prefix=prefix,
#     739     versions=versions,
#     740 ):
#     741     if c["type"] == "directory":
#     742         dirs.append(c)
#
# File ~/my_project/AI/venvAI/lib/python3.12/site-packages/s3fs/core.py:784, in S3FileSystem._iterdir(self, bucket, max_items, delimiter, prefix, versions)
#     776     config.update(MaxItems=max_items, PageSize=2 * max_items)
#     777 it = pag.paginate(
#     778     Bucket=bucket,
#     779     Prefix=prefix,
#    (...)
#     782     **self.req_kw,
#     783 )
# --> 784 async for i in it:
#     785     for l in i.get("CommonPrefixes", []):
#     786         c = {
#     787             "Key": l["Prefix"][:-1],
#     788             "Size": 0,
#     789             "StorageClass": "DIRECTORY",
#     790             "type": "directory",
#     791         }
#
# File ~/my_project/AI/venvAI/lib/python3.12/site-packages/aiobotocore/paginate.py:30, in AioPageIterator.__anext__(self)
#      27 self._inject_starting_params(current_kwargs)
#      29 while True:
# ---> 30     response = await self._make_request(current_kwargs)
#      31     parsed = self._extract_parsed_response(response)
#      32     if first_request:
#      33         # The first request is handled differently.  We could
#      34         # possibly have a resume/starting token that tells us where
#      35         # to index into the retrieved page.
#
# File ~/my_project/AI/venvAI/lib/python3.12/site-packages/aiobotocore/client.py:394, in AioBaseClient._make_api_call(self, operation_name, api_params)
#     390     maybe_compress_request(
#     391         self.meta.config, request_dict, operation_model
#     392     )
#     393     apply_request_checksum(request_dict)
# --> 394     http, parsed_response = await self._make_request(
#     395         operation_model, request_dict, request_context
#     396     )
#     398 await self.meta.events.emit(
#     399     f'after-call.{service_id}.{operation_name}',
#     400     http_response=http,
#    (...)
#     403     context=request_context,
#     404 )
#     406 if http.status_code >= 300:
#
# File ~/my_project/AI/venvAI/lib/python3.12/site-packages/aiobotocore/client.py:420, in AioBaseClient._make_request(self, operation_model, request_dict, request_context)
#     416 async def _make_request(
#     417     self, operation_model, request_dict, request_context
#     418 ):
#     419     try:
# --> 420         return await self._endpoint.make_request(
#     421             operation_model, request_dict
#     422         )
#     423     except Exception as e:
#     424         await self.meta.events.emit(
#     425             f'after-call-error.{self._service_model.service_id.hyphenize()}.{operation_model.name}',
#     426             exception=e,
#     427             context=request_context,
#     428         )
#
# File ~/my_project/AI/venvAI/lib/python3.12/site-packages/aiobotocore/endpoint.py:96, in AioEndpoint._send_request(self, request_dict, operation_model)
#      94 context = request_dict['context']
#      95 self._update_retries_context(context, attempts)
# ---> 96 request = await self.create_request(request_dict, operation_model)
#      97 success_response, exception = await self._get_response(
#      98     request, operation_model, context
#      99 )
#     100 while await self._needs_retry(
#     101     attempts,
#     102     operation_model,
#    (...)
#     105     exception,
#     106 ):
#
# File ~/my_project/AI/venvAI/lib/python3.12/site-packages/aiobotocore/endpoint.py:84, in AioEndpoint.create_request(self, params, operation_model)
#      82     service_id = operation_model.service_model.service_id.hyphenize()
#      83     event_name = f'request-created.{service_id}.{operation_model.name}'
# ---> 84     await self._event_emitter.emit(
#      85         event_name,
#      86         request=request,
#      87         operation_name=operation_model.name,
#      88     )
#      89 prepared_request = self.prepare_request(request)
#      90 return prepared_request
#
# File ~/my_project/AI/venvAI/lib/python3.12/site-packages/aiobotocore/hooks.py:68, in AioHierarchicalEmitter._emit(self, event_name, kwargs, stop_on_response)
#      65 logger.debug('Event %s: calling handler %s', event_name, handler)
#      67 # Await the handler if its a coroutine.
# ---> 68 response = await resolve_awaitable(handler(**kwargs))
#      69 responses.append((handler, response))
#      70 if stop_on_response and response is not None:
#
# File ~/my_project/AI/venvAI/lib/python3.12/site-packages/aiobotocore/_helpers.py:6, in resolve_awaitable(obj)
#       4 async def resolve_awaitable(obj):
#       5     if inspect.isawaitable(obj):
# ----> 6         return await obj
#       8     return obj
#
# File ~/my_project/AI/venvAI/lib/python3.12/site-packages/aiobotocore/signers.py:24, in AioRequestSigner.handler(self, operation_name, request, **kwargs)
#      19 async def handler(self, operation_name=None, request=None, **kwargs):
#      20     # This is typically hooked up to the "request-created" event
#      21     # from a client's event emitter.  When a new request is created
#      22     # this method is invoked to sign the request.
#      23     # Don't call this method directly.
# ---> 24     return await self.sign(operation_name, request)
#
# File ~/my_project/AI/venvAI/lib/python3.12/site-packages/aiobotocore/signers.py:90, in AioRequestSigner.sign(self, operation_name, request, region_name, signing_type, expires_in, signing_name)
#      87     else:
#      88         raise e
# ---> 90 auth.add_auth(request)
#
# File ~/my_project/AI/venvAI/lib/python3.12/site-packages/botocore/auth.py:423, in SigV4Auth.add_auth(self, request)
#     421 def add_auth(self, request):
#     422     if self.credentials is None:
# --> 423         raise NoCredentialsError()
#     424     datetime_now = datetime.datetime.utcnow()
#     425     request.context['timestamp'] = datetime_now.strftime(SIGV4_TIMESTAMP)
#
# NoCredentialsError: Unable to locate credentials
